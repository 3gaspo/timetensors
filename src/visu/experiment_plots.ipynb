# %% [markdown]
# # TimeTensor Experiment Plots
#
# Interactive plotting dashboard for artifacts created by `scripts.experiment`, `scripts.train`, and `scripts.evaluate`. Implementation lives in `experiment_plots.py`.

# %%
from pathlib import Path

on_drive = False
if on_drive:
    from google.colab import drive
    drive.mount("/content/drive")
    data_path = Path("/content/drive/MyDrive/Recherche/Thèse Gaspard/Datasets")
    # %cd "/content/drive/MyDrive/Recherche/Thèse Gaspard/Codes/timetensors/src"
else:
    project_src = Path.cwd().parent if Path.cwd().name == "visu" else Path.cwd() / "src"
    if not project_src.is_dir():
        project_src = Path.cwd()
    # %cd $project_src
    data_path = Path("../datasets")

# %%
from visu.experiment_plots import display_dashboard

display_dashboard()
